# %%
# !pip install apyori

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_csv('1604001 Depression Analysis.csv',head=None)

# %%
len(store_data.columns)
len(store_data)
# Out:
# 1004

# %%
store_data.head()
# Out:
#              Timestamp Which year are you in? How are you feeling right now?  \
# 0  11/29/2020 10:08:31               1st year                           Good
# 1  11/29/2020 10:11:20               1st year                         Normal
# 2  11/29/2020 11:10:42               2nd year                           Good
# 3  11/29/2020 11:21:29               2nd year                         Normal
# 4  11/29/2020 11:22:51               1st year                           Good
#
#    On a scale of 1-100, how would you express this feeling? Gender  Age  \
# 0                                                 70          Male   18
# 1                                                 60          Male   18
# 2                                                 70          Male   19
# 3                                                 50          Male   19
# 4                                                 90          Male   18
#
#   Your location ? Relationship status  \
# ...

# %%
records = []
for i in range(0, 1005):
    records.append([str(store_data.values[i, j]) for j in range(0, 21)])

# %%
association_rules = apriori(records, min_support=0.0765, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print(len(association_results))
print(association_results[0])
# Out:
# 2136
# RelationRecord(items=frozenset({'19', '1'}), support=0.15, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1'}), items_add=frozenset({'19'}), confidence=0.8152173913043478, lift=3.019323671497584), OrderedStatistic(items_base=frozenset({'19'}), items_add=frozenset({'1'}), confidence=0.5555555555555555, lift=3.019323671497584)])

# %%
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    print("Support: " + str(item[1]))
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: 19 -> 1
# Support: 0.15
# Confidence: 0.8152173913043478
# Lift: 3.019323671497584
# ...
# Rule: 1 -> 1st year
# Support: 0.152
# Confidence: 0.8260869565217391
# Lift: 3.082414016872161
# ...
# Rule: 1 -> Broken Up
# Support: 0.154
# Confidence: 0.8369565217391305
# Lift: 5.166398282340311
# ...
# Rule: 1 -> Very bad
# Support: 0.18
# Confidence: 0.9782608695652174
# Lift: 5.434782608695652
# ...
# Rule: 19 -> 1st year
# Support: 0.261
# Confidence: 0.9666666666666667
# Lift: 3.606965174129353
# ...
# Rule: 19 -> Broken Up
# Support: 0.135
# Confidence: 0.5
# Lift: 3.0864197530864197
# ...
# Rule: 19 -> Very bad
# Support: 0.15
# Confidence: 0.5555555555555555
# Lift: 3.0864197530864192
# ...
# Rule: 1st year -> Broken Up
# Support: 0.135
# Confidence: 0.503731343283582
# Lift: 3.1094527363184077
# ...
# Rule: Very bad -> 1st year
# Support: 0.151
# Confidence: 0.5634328358208954
# Lift: 3.130182421227197
# ...
# Rule: 2 -> 30
# Support: 0.147
# Confidence: 0.4696485623003195
# Lift: 3.194888178913738
# ...
# Rule: 20 -> 2nd year
# ...
